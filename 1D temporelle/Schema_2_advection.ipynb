# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np

#Paramètres du problème en concentration
c_0=1000
sigma=1000
c=0.01

#Paramètres de discrétisation de ©l'espace x
n=10
dx=1/n
x=np.zeros(n,dtype=np.double)
for i in range(1,n):
    x[i]=x[i-1]+(1/n)
#Paramètres de discrétisation du temps t
m=10
dt=1/m
t=np.zeros(m,dtype=np.double)
for i in range(1,m):
    t[i]=t[i-1]+(1/m)
#Paramètre alpha = c*dt/2*dx
alpha=(c*dt)/(dx)
#Matrice des conditions initiales
B_0=np.zeros(n,dtype=np.double)
for i in range(0,n):
    B_0[i]=np.cos(x[i])

#Matrice des composantes temporelles
sol=np.zeros((m, n))
for i in range(0,n):
    sol[0,i]=B_0[i]
A=np.eye(n)
for i in range(0,n):
    for j in range(0,n):
        if(j==i+1):
            A[i,j]=alpha
        elif(j==i):
            A[i,j]=1-alpha
for i in range(0,m):
    power = np.linalg.matrix_power(A, i)
    result=np.dot(power,B_0)
    for j in range(0,n):
        sol[i,j]=result[j]
print(sol)
#Matrice de la solution en fonction de t 
def f(x, t):
    return np.cos(x+(c*t))
# Out:
# [[1.         0.99500417 0.98006658 0.95533649 0.92106099 0.87758256
#   0.82533561 0.76484219 0.69670671 0.62160997]
#  [0.99995004 0.99485479 0.97981928 0.95499373 0.92062621 0.87706009
#   0.82473068 0.76416083 0.69595574 0.61539387]
#  [0.99989909 0.99470443 0.97957102 0.95465006 0.92019055 0.8765368
#   0.82412498 0.76347878 0.69515012 0.60923993]
#  [0.99984714 0.9945531  0.97932181 0.95430546 0.91975401 0.87601268
#   0.82351852 0.7627955  0.69429102 0.60314753]
#  [0.9997942  0.99440079 0.97907165 0.95395995 0.9193166  0.87548774
#   0.82291129 0.76211045 0.69337959 0.59711606]
#  [0.99974027 0.9942475  0.97882053 0.95361352 0.91887831 0.87496197
#   0.82230328 0.76142314 0.69241695 0.59114489]
#  [0.99968534 0.99409323 0.97856846 0.95326616 0.91843915 0.87443539
#   0.82169448 0.76073308 0.69140423 0.58523345]
#  [0.99962942 0.99393798 0.97831544 0.95291789 0.91799911 0.87390798
#   0.82108487 0.76003979 0.69034252 0.57938111]
#  [0.9995725  0.99378175 0.97806146 0.95256871 0.9175582  0.87337975
#   0.82047442 0.75934282 0.68923291 0.5735873 ]
#  [0.9995146  0.99362455 0.97780654 0.9522186  0.91711641 0.87285069
#   0.8198631  0.75864172 0.68807645 0.56785143]]

# %% [markdown]
# # Plot

# %%
def create_3d_plot():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    X1, Y1 = np.meshgrid(x,t)
    result = f(X1, Y1)
    ax.plot_surface(X1, Y1, sol, cmap='viridis')
    ax.plot_surface(X1, Y1, result, cmap='inferno')
    return fig

# %%
root = tk.Tk()
root.title("Tracé 3D interactif")

# Créez le tracé 3D
fig = create_3d_plot()

# Créez un canevas Tkinter pour afficher le tracé
canvas = FigureCanvasTkAgg(fig, master=root)
canvas.get_tk_widget().pack()

# Fonction pour effectuer une rotation du tracé en réponse à la souris
def on_mouse_move(event):
    if event.button == 'up':
        fig.canvas.release(event)
    else:
        fig.canvas.motion_notify(event)
def on_mouse_scroll(event):
    if event.button == 'up':
        scale = 1.1
    else:
        scale = 1 / 1.1

    ax = fig.gca(projection='3d')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    zlim = ax.get_zlim()
    ax.set_xlim(
        (event.xdata - xlim[0]) * scale + xlim[0],
        (event.xdata - xlim[1]) * scale + xlim[1]
    )
    ax.set_ylim(
        (event.ydata - ylim[0]) * scale + ylim[0],
        (event.ydata - ylim[1]) * scale + ylim[1]
    )
    ax.set_zlim(
        (event.ydata - zlim[0]) * scale + zlim[0],
        (event.ydata - zlim[1]) * scale + zlim[1]
    )

canvas.mpl_connect('motion_notify_event', on_mouse_move)
canvas.mpl_connect('button_release_event', on_mouse_move)
canvas.mpl_connect('scroll_event', on_mouse_scroll)
# Lancez l'application Tkinter
root.mainloop()
# Out:
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
# Traceback (most recent call last):
#   File "/Users/rachidaitjalloul/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/var/folders/zb/_d8dsvp17n54wwjbqt8lknz80000gn/T/ipykernel_2752/2055291923.py", line 16, in on_mouse_move
#     fig.canvas.motion_notify(event)
# AttributeError: 'FigureCanvasTkAgg' object has no attribute 'motion_notify'
